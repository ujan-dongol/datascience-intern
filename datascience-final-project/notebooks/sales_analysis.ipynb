# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/sales_data.csv")
df.head()
# Out:
#          Date    Product Region  Sales  Revenue
# 0  2023-01-01  Product A   East    120     2400
# 1  2023-01-02  Product B   West    150     3000
# 2  2023-01-03  Product C  North    200     5000
# 3  2023-01-04  Product A  South    180     3600
# 4  2023-01-05  Product B   East    130     2600

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     6 non-null      object
#  1   Product  6 non-null      object
#  2   Region   6 non-null      object
#  3   Sales    6 non-null      int64
#  4   Revenue  6 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 372.0+ bytes
#             Sales      Revenue
# count    6.000000     6.000000
# mean   158.333333  3466.666667
# std     30.605010  1001.332446
# min    120.000000  2400.000000
# 25%    135.000000  2700.000000
# 50%    160.000000  3300.000000
# 75%    177.500000  4050.000000
# max    200.000000  5000.000000

# %%
plt.figure()
plt.plot(df["Date"], df["Sales"])
plt.title("Sales Trend Over Time")
plt.xticks(rotation=45)
plt.savefig("../outputs/sales_trend.png")
plt.show()

# %%
top_products = df.groupby("Product")["Revenue"].sum()

top_products.plot(kind="bar")
plt.title("Top Selling Products")
plt.savefig("../outputs/top_products.png")
plt.show()

# %%
sns.histplot(df["Revenue"], bins=5)
plt.title("Revenue Distribution")
plt.savefig("../outputs/revenue_distribution.png")
plt.show()
